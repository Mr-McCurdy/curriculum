# %%
# %pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import json
import os

# %%
#Define path
SECRETS_FILE = '/Users/gmccurdy/repos/curriculum/scripts/utilities/secrets.json'

# Load secrets
with open(SECRETS_FILE, 'r') as file:
    secrets = json.load(file)

# Assign variables from the secrets
API_URL = secrets.get('API_URL')
API_KEY = secrets.get('API_KEY')
COURSE_ID = secrets.get('COURSE_ID_STATISTICS')

#Define headers
headers = {
    'Authorization': f'Bearer {API_KEY}',
    'Content-Type': 'application/json'
}

# %%
# Create the quiz
quiz_title = input('Quiz Title')
quiz_description = input('Quiz Description')
quiz_data = {
    'quiz': {
        'title': quiz_title,
        'description': f'<p>{quiz_description}</p>',
        'quiz_type': 'assignment',
        'published': False
    }
}

create_quiz_url = f'{API_URL}/api/v1/courses/{COURSE_ID}/quizzes'
response = requests.post(create_quiz_url, headers=headers, json=quiz_data)

if response.status_code == 200:
    quiz = response.json()
    quiz_id = quiz['id']
    print(f'Quiz created successfully with ID: {quiz_id}')
else:
    print('Failed to create quiz')
    print(f"Status Code: {response.status_code}")
    print(response.text)
# Out:
# Quiz created successfully with ID: 44098

# %%
numerical_questions = [
    {
        'question_name': 'Probability Between 49 and 61 grams',
        'question_type': 'numerical_question',
        'question_text': '''The weight of a package is normally distributed with a mean of 55 grams and a standard deviation of 6 grams. What is the probability that a randomly selected package weighs between 49 and 61 grams?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.6826'  # 68.26%
            }
        ]
    },
    {
        'question_name': 'Probability Student Scores Between 440 and 600',
        'question_type': 'numerical_question',
        'question_text': '''A standardized test has scores that are normally distributed with a mean of 520 and a standard deviation of 80. What is the probability that a student scores between 440 and 600?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.6826'  # Approximately 68.26%
            }
        ]
    },
    {
        'question_name': 'Probability Tree Taller Than 195 cm',
        'question_type': 'numerical_question',
        'question_text': '''The height of trees in a forest is normally distributed with a mean of 180 cm and a standard deviation of 15 cm. What is the probability that a randomly selected tree is taller than 195 cm?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.1587'  # Approximately 15.87%
            }
        ]
    },
    {
        'question_name': 'Mean of Sampling Distribution of Sample Mean',
        'question_type': 'numerical_question',
        'question_text': '''A population has a mean μ = 200 and a standard deviation σ = 25. For a sample of size 36, find the mean of the sampling distribution of the sample mean \(\bar{x}\).''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '200'  # μx̄ = μ
            }
        ]
    },
    {
        'question_name': 'Probability IQ Between 95 and 115',
        'question_type': 'numerical_question',
        'question_text': '''IQ scores in a population are normally distributed with a mean of 100 and a standard deviation of 15. What is the probability that a randomly selected person has an IQ between 95 and 115?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.6826'  # Approximately 68.26%
            }
        ]
    },
    {
        'question_name': 'Probability Task Takes More Than 52 Minutes',
        'question_type': 'numerical_question',
        'question_text': '''The time to complete a task is normally distributed with a mean of 45 minutes and a standard deviation of 7 minutes. What is the probability that the task takes more than 52 minutes?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.0668'  # Approximately 6.68%
            }
        ]
    },
    {
        'question_name': 'Probability Student Scores Less Than 58',
        'question_type': 'numerical_question',
        'question_text': '''A test score is normally distributed with a mean of 65 and a standard deviation of 9. What is the probability that a student scores less than 58?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.3085'  # Approximately 30.85%
            }
        ]
    },
    {
        'question_name': 'Probability Pipe Diameter Greater Than 5.8 cm',
        'question_type': 'numerical_question',
        'question_text': '''The diameter of pipes manufactured by a company is normally distributed with a mean of 5.5 cm and a standard deviation of 0.3 cm. What is the probability that a randomly selected pipe has a diameter greater than 5.8 cm?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.0228'  # Approximately 2.28%
            }
        ]
    },
    {
        'question_name': 'Probability Bottle Contains Between 480 ml and 520 ml',
        'question_type': 'numerical_question',
        'question_text': '''A machine fills bottles with soda, and the fill amount is normally distributed with a mean of 500 ml and a standard deviation of 20 ml. What is the probability that a bottle contains between 480 ml and 520 ml of soda?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.6826'  # Approximately 68.26%
            }
        ]
    },
    {
        'question_name': 'Probability Bulb Lasts Less Than 950 Hours',
        'question_type': 'numerical_question',
        'question_text': '''The lifespan of a type of light bulb is normally distributed with a mean of 1000 hours and a standard deviation of 100 hours. What is the probability that a randomly selected bulb lasts less than 950 hours?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.3085'  # Approximately 30.85%
            }
        ]
    },
    {
        'question_name': 'Probability Screw Diameter Between 4.7 mm and 4.9 mm',
        'question_type': 'numerical_question',
        'question_text': '''The diameter of screws produced by a machine is normally distributed with a mean of 4.8 mm and a standard deviation of 0.15 mm. What is the probability that a randomly selected screw has a diameter between 4.7 mm and 4.9 mm?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.6826'  # Approximately 68.26%
            }
        ]
    },
    {
        'question_name': 'Probability Fish Longer Than 28 cm',
        'question_type': 'numerical_question',
        'question_text': '''A population of fish has lengths normally distributed with a mean of 25 cm and a standard deviation of 2 cm. What is the probability that a randomly selected fish is longer than 28 cm?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.0228'  # Approximately 2.28%
            }
        ]
    },
    {
        'question_name': 'Mean and Standard Deviation of Sample Mean (μ=200, σ=25, n=36)',
        'question_type': 'numerical_question',
        'question_text': '''A population has a mean μ = 200 and a standard deviation σ = 25. For a sample of size 36, find the standard deviation of the sampling distribution of the sample mean \(\bar{x}\).''',
        'points_possible': 2,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '4.1667'  # μx̄ = μ, SE = σ/√n
            }
        ]
    },
    {
        'question_name': 'Standard Error of Sample Mean (μ=75, σ=15, n=64)',
        'question_type': 'numerical_question',
        'question_text': '''If a population has a mean μ = 75 and a standard deviation σ = 15, what is the standard error of the sample mean for a sample size of 64?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '1.875'  # SE = 15 / sqrt(64) = 1.875
            }
        ]
    },
    {
        'question_name': 'Probability Sample Mean Lifetime Between 790 and 810 Hours',
        'question_type': 'numerical_question',
        'question_text': '''The lifetimes of batteries are normally distributed with a mean of 800 hours and a standard deviation of 50 hours. If a sample of 25 batteries is selected, what is the probability that the sample mean lifetime is between 790 and 810 hours?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.6826'  # Approximately 68.26%
            }
        ]
    },
    {
        'question_name': 'Probability Sample Mean Weight More Than 152 grams',
        'question_type': 'numerical_question',
        'question_text': '''A factory produces widgets with a mean weight of 150 grams and a standard deviation of 10 grams. If a random sample of 49 widgets is selected, what is the probability that the sample mean weight is more than 152 grams?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.0668'  # Approximately 6.68%
            }
        ]
    },
    {
        'question_name': 'Probability Sample Mean Height Less Than 168 cm',
        'question_type': 'numerical_question',
        'question_text': '''The heights of students in a university are normally distributed with a mean of 170 cm and a standard deviation of 8 cm. What is the probability that the sample mean height of a sample of 25 students is less than 168 cm?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.1056'  # Approximately 10.56%
            }
        ]
    },
    {
        'question_name': 'Mean and Standard Deviation of Sampling Distribution (μ=500, σ=80, n=100)',
        'question_type': 'numerical_question',
        'question_text': '''A population has a mean μ = 500 and a standard deviation σ = 80. For a sample of size 100, calculate the mean of the sampling distribution of \(\bar{x}\).''',
        'points_possible': 2,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '500'  # μx̄ = μ, SE = σ/√n
            }
        ]
    },
    {
        'question_name': 'Probability Sample Mean Time Between 29 and 31 Minutes',
        'question_type': 'numerical_question',
        'question_text': '''The amount of time (in minutes) that customers spend in a bank is normally distributed with a mean of 30 minutes and a standard deviation of 5 minutes. What is the probability that the sample mean time for a sample of 25 customers is between 29 and 31 minutes?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.6826'  # Approximately 68.26%
            }
        ]
    },
    {
        'question_name': 'Mean and Standard Deviation of Sampling Distribution (μ=120, σ=15, n=64)',
        'question_type': 'numerical_question',
        'question_text': '''A population has a mean μ = 120 and a standard deviation σ = 15. If we take all possible samples of size 64, what will be the standard deviation of the sampling distribution of \(\bar{x}\)?''',
        'points_possible': 2,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '1.875'  # μx̄ = μ, SE = σ/√n
            }
        ]
    },
    {
        'question_name': 'Probability Sample Mean Diameter Greater Than 4.55 mm',
        'question_type': 'numerical_question',
        'question_text': '''The diameters of screws produced by a machine are normally distributed with a mean of 4.5 mm and a standard deviation of 0.1 mm. If a sample of 16 screws is selected, what is the probability that the sample mean diameter is greater than 4.55 mm?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.0228'  # Approximately 2.28%
            }
        ]
    },
    {
        'question_name': 'Probability Sample Mean Weight More Than 155 grams',
        'question_type': 'numerical_question',
        'question_text': '''The weight of apples in an orchard is normally distributed with a mean of 150 grams and a standard deviation of 30 grams. If a random sample of 36 apples is selected, what is the probability that the sample mean weight is more than 155 grams?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.1587'  # Approximately 15.87%
            }
        ]
    },
    {
        'question_name': 'Probability Sample Mean Differs by More Than 5 Units',
        'question_type': 'numerical_question',
        'question_text': '''A sample of 64 observations is taken from a population with a standard deviation of 32. What is the probability that the sample mean differs from the population mean by more than 5 units?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.0455'  # Approximately 4.55%
            }
        ]
    },
    {
        'question_name': 'Probability Sample Mean Greater Than 4.55 mm',
        'question_type': 'numerical_question',
        'question_text': '''The diameters of screws produced by a machine are normally distributed with a mean of 4.5 mm and a standard deviation of 0.1 mm. If a sample of 16 screws is selected, what is the probability that the sample mean diameter is greater than 4.55 mm?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.0228'  # Approximately 2.28%
            }
        ]
    },
    {
        'question_name': 'Probability Sample Proportion Less Than 0.15',
        'question_type': 'numerical_question',
        'question_text': '''In a population, p = 0.20. For a sample of size 150, what is the probability that the sample proportion \(\hat{p}\) is less than 0.15?''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.0625'  # Approximately 6.25%
            }
        ]
    },
    {
        'question_name': 'Calculating Standard Error for Sample Proportion',
        'question_type': 'numerical_question',
        'question_text': '''A population has a proportion p = 0.40. For a sample size of 150, calculate the standard deviation of the sampling distribution of the sample proportion \(\hat{p}\).''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.04'  # SEp = sqrt(p(1-p)/n) = sqrt(0.4*0.6/150) = 0.04
            }
        ]
    },
    {
        'question_name': 'Probability Sample Proportion Greater Than 0.65',
        'question_type': 'numerical_question',
        'question_text': '''A population has a proportion p = 0.60. For a sample size of 200, what is the probability that the sample proportion \(\hat{p}\) is greater than 0.65? Assume the normal approximation is appropriate.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '0.0228'  # Approximately 2.28%
            }
        ]
    }
    # Add more numerical questions as needed to reach around 25
]

numerical_questions += [
    {
        'question_name': 'Z-score Calculation for IQ Score',
        'question_type': 'numerical_question',
        'question_text': '''An individual scores 130 on an IQ test. If the population mean IQ is 100 with a standard deviation of 15, calculate the z-score for this individual.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '2.0000'  # z = (130 - 100) / 15 = 2.0
            }
        ]
    },
    {
        'question_name': 'Z-score for Test Score',
        'question_type': 'numerical_question',
        'question_text': '''A student scored 600 on a standardized test where the mean score is 520 and the standard deviation is 80. Calculate the z-score for this test score.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '1.0000'  # z = (600 - 520) / 80 = 1.0
            }
        ]
    },
    {
        'question_name': 'Z-score for Tree Height',
        'question_type': 'numerical_question',
        'question_text': '''A tree in a forest measures 195 cm in height. Given that the mean height is 180 cm with a standard deviation of 15 cm, calculate the z-score for this tree's height.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '1.0000'  # z = (195 - 180) / 15 = 1.0
            }
        ]
    },
    {
        'question_name': 'Z-score for Value Less Than 70',
        'question_type': 'numerical_question',
        'question_text': '''In a normal distribution with a mean of 85 and a standard deviation of 12, calculate the z-score for a value of 70.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '-1.0417'  # z = (70 - 85) / 12 ≈ -1.0417
            }
        ]
    },
    {
        'question_name': 'Z-score for Task Time',
        'question_type': 'numerical_question',
        'question_text': '''The time to complete a task is normally distributed with a mean of 45 minutes and a standard deviation of 7 minutes. Calculate the z-score for a task that takes 52 minutes.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '1.0000'  # z = (52 - 45) / 7 = 1.0
            }
        ]
    },
    {
        'question_name': 'Z-score for Test Score Less Than 58',
        'question_type': 'numerical_question',
        'question_text': '''A test score is normally distributed with a mean of 65 and a standard deviation of 9. Calculate the z-score for a score of 58.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '-0.7778'  # z = (58 - 65) / 9 ≈ -0.7778
            }
        ]
    },
    {
        'question_name': 'Z-score for Pipe Diameter Greater Than 5.8 cm',
        'question_type': 'numerical_question',
        'question_text': '''The diameter of pipes manufactured by a company is normally distributed with a mean of 5.5 cm and a standard deviation of 0.3 cm. Calculate the z-score for a pipe diameter of 5.8 cm.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '1.0000'  # z = (5.8 - 5.5) / 0.3 = 1.0
            }
        ]
    },
    {
        'question_name': 'Z-score for Sample Mean Lifetime',
        'question_type': 'numerical_question',
        'question_text': '''The lifespans of batteries are normally distributed with a mean of 800 hours and a standard deviation of 50 hours. For a sample of 25 batteries, calculate the z-score for a sample mean lifetime of 790 hours.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '-2.0000'  # SE = 50 / sqrt(25) = 10; z = (790 - 800) / 10 = -1.0
            }
        ]
    },
    {
        'question_name': 'Z-score for Sample Mean Height',
        'question_type': 'numerical_question',
        'question_text': '''The heights of students in a university are normally distributed with a mean of 170 cm and a standard deviation of 8 cm. For a sample of 25 students, calculate the z-score for a sample mean height of 168 cm.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '-1.2500'  # SE = 8 / sqrt(25) = 1.6; z = (168 - 170) / 1.6 = -1.25
            }
        ]
    },
    {
        'question_name': 'Z-score for Sample Mean Diameter',
        'question_type': 'numerical_question',
        'question_text': '''The diameters of screws produced by a machine are normally distributed with a mean of 4.5 mm and a standard deviation of 0.1 mm. For a sample of 16 screws, calculate the z-score for a sample mean diameter of 4.55 mm.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '2.0000'  # SE = 0.1 / sqrt(16) = 0.025; z = (4.55 - 4.5) / 0.025 = 2.0
            }
        ]
    },
    {
        'question_name': 'Z-score for Sample Proportion Less Than 0.15',
        'question_type': 'numerical_question',
        'question_text': '''In a population where p = 0.20, for a sample size of 150, calculate the z-score for a sample proportion \(\hat{p}\) of 0.15.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '-1.5333'  # SE = sqrt(0.2*0.8/150) ≈ 0.0327; z = (0.15 - 0.20)/0.0327 ≈ -1.5333
            }
        ]
    }
]

# %%
essay_questions = [

]

# %%
multiple_choice_questions = [
    {
        'question_name': 'Standard Error Calculation',
        'question_type': 'multiple_choice_question',
        'question_text': '''A population has a mean μ = 200 and a standard deviation σ = 25. For a sample of size 36, what is the standard error (SE) of the sample mean \(\bar{x}\)?''',
        'points_possible': 1,
        'answers': [
            {'text': '4.1667', 'weight': 100},  # Correct answer
            {'text': '5.0000', 'weight': 0},
            {'text': '3.1250', 'weight': 0},
            {'text': '6.2500', 'weight': 0},
            {'text': '2.5000', 'weight': 0}
        ]
    },
    {
        'question_name': 'Normal Approximation Appropriateness',
        'question_type': 'multiple_choice_question',
        'question_text': '''A population has a proportion p = 0.35. For a sample size of 120, is the normal approximation appropriate for the sampling distribution of \(\hat{p}\)?''',
        'points_possible': 1,
        'answers': [
            {'text': 'Yes, because np and n(1-p) are both greater than 10.', 'weight': 100},  # Correct
            {'text': 'No, because np < 10.', 'weight': 0},
            {'text': 'No, because n(1-p) < 10.', 'weight': 0},
            {'text': 'Yes, because n is greater than 30.', 'weight': 0},
            {'text': 'No, because p is not 0.5.', 'weight': 0}
        ]
    },
    {
        'question_name': 'Sample Proportion Mean',
        'question_type': 'multiple_choice_question',
        'question_text': '''What is the mean of the sampling distribution of the sample proportion \(\hat{p}\) if the population proportion p = 0.25?''',
        'points_possible': 1,
        'answers': [
            {'text': '0.25', 'weight': 100},  # Correct answer
            {'text': '0.30', 'weight': 0},
            {'text': '0.20', 'weight': 0},
            {'text': '0.35', 'weight': 0},
            {'text': '0.40', 'weight': 0}
        ]
    },
    {
        'question_name': 'Probability Between Two Z-scores',
        'question_type': 'multiple_choice_question',
        'question_text': '''If \( Z_1 = -1.0 \) and \( Z_2 = 1.0 \) in a standard normal distribution, what is \( P(Z_1 < Z < Z_2) \)?''',
        'points_possible': 1,
        'answers': [
            {'text': '0.6826', 'weight': 100},  # Correct answer
            {'text': '0.8413', 'weight': 0},
            {'text': '0.5000', 'weight': 0},
            {'text': '0.9545', 'weight': 0},
            {'text': '0.1587', 'weight': 0}
        ]
    },
    {
        'question_name': 'Probability Less Than a Z-score',
        'question_type': 'multiple_choice_question',
        'question_text': '''What is \( P(Z < -1.25) \) in a standard normal distribution?''',
        'points_possible': 1,
        'answers': [
            {'text': '0.1056', 'weight': 100},  # Correct answer
            {'text': '0.2000', 'weight': 0},
            {'text': '0.1587', 'weight': 0},
            {'text': '0.3085', 'weight': 0},
            {'text': '0.6915', 'weight': 0}
        ]
    },
    {
        'question_name': 'Standard Error of Sample Proportion (p=0.20, n=150)',
        'question_type': 'multiple_choice_question',
        'question_text': '''For a population proportion p = 0.20 and a sample size of 150, what is the standard error \( SE_{\hat{p}} \) of the sample proportion \(\hat{p}\)?''',
        'points_possible': 1,
        'answers': [
            {'text': '0.0327', 'weight': 100},  # Correct answer
            {'text': '0.04', 'weight': 0},
            {'text': '0.0280', 'weight': 0},
            {'text': '0.0350', 'weight': 0},
            {'text': '0.0250', 'weight': 0}
        ]
    },
    {
        'question_name': 'Probability Sample Proportion Greater Than 0.45',
        'question_type': 'multiple_choice_question',
        'question_text': '''In a population with p = 0.42, for a sample of size 100, what is the probability that the sample proportion \(\hat{p}\) is greater than 0.45?''',
        'points_possible': 1,
        'answers': [
            {'text': '0.2714', 'weight': 100},  # Correct answer
            {'text': '0.5000', 'weight': 0},
            {'text': '0.1587', 'weight': 0},
            {'text': '0.3085', 'weight': 0},
            {'text': '0.4000', 'weight': 0}
        ]
    },
    {
        'question_name': 'Z-score Calculation',
        'question_type': 'multiple_choice_question',
        'question_text': '''Calculate the z-score for a value X = 168 cm, given μ = 170 cm and SE = 1.6 cm.''',
        'points_possible': 1,
        'answers': [
            {'text': '-1.25', 'weight': 100},  # Correct answer
            {'text': '1.25', 'weight': 0},
            {'text': '-0.625', 'weight': 0},
            {'text': '0.625', 'weight': 0},
            {'text': '-2.00', 'weight': 0}
        ]
    },
    {
        'question_name': 'Probability Sample Mean Less Than 168 cm',
        'question_type': 'multiple_choice_question',
        'question_text': '''What is the probability that the sample mean height is less than 168 cm, given μ = 170 cm, σ = 8 cm, and n = 25?''',
        'points_possible': 1,
        'answers': [
            {'text': '0.1056', 'weight': 100},  # Correct answer
            {'text': '0.1587', 'weight': 0},
            {'text': '0.3085', 'weight': 0},
            {'text': '0.5000', 'weight': 0},
            {'text': '0.8413', 'weight': 0}
        ]
    },
    {
        'question_name': 'Probability Between Two Sample Means',
        'question_type': 'multiple_choice_question',
        'question_text': '''If the sample mean \(\bar{x}\) is 4.55 mm, the population mean μ = 4.5 mm, SE = 0.025 mm, what is the z-score?''',
        'points_possible': 1,
        'answers': [
            {'text': '2.0', 'weight': 100},  # Correct answer
            {'text': '1.5', 'weight': 0},
            {'text': '2.5', 'weight': 0},
            {'text': '1.0', 'weight': 0},
            {'text': '3.0', 'weight': 0}
        ]
    },
    {
        'question_name': 'Standard Error for Sample Mean (σ=8, n=25)',
        'question_type': 'multiple_choice_question',
        'question_text': '''Calculate the standard error (SE) for the sample mean when σ = 8 and n = 25.''',
        'points_possible': 1,
        'answers': [
            {'text': '1.6', 'weight': 100},  # Correct answer
            {'text': '2.0', 'weight': 0},
            {'text': '1.0', 'weight': 0},
            {'text': '2.4', 'weight': 0},
            {'text': '1.2', 'weight': 0}
        ]
    },
    {
        'question_name': 'Normal Approximation for p = 0.25, n = 200',
        'question_type': 'multiple_choice_question',
        'question_text': '''Is the normal approximation appropriate for a population proportion p = 0.25 and sample size n = 200?''',
        'points_possible': 1,
        'answers': [
            {'text': 'Yes, because np and n(1-p) are both greater than 10.', 'weight': 100},  # Correct answer
            {'text': 'No, because p is too low.', 'weight': 0},
            {'text': 'No, because n is too small.', 'weight': 0},
            {'text': 'Yes, because p > 0.1.', 'weight': 0},
            {'text': 'No, because np < 10.', 'weight': 0}
        ]
    },
    {
        'question_name': 'Probability Sample Proportion Less Than 0.15',
        'question_type': 'multiple_choice_question',
        'question_text': '''In a population with p = 0.20, for a sample size of 150, what is the probability that the sample proportion \(\hat{p}\) is less than 0.15?''',
        'points_possible': 1,
        'answers': [
            {'text': '0.0625', 'weight': 100},  # Correct answer
            {'text': '0.1587', 'weight': 0},
            {'text': '0.3085', 'weight': 0},
            {'text': '0.0250', 'weight': 0},
            {'text': '0.1056', 'weight': 0}
        ]
    },
    {
        'question_name': 'Standard Error Calculation for p = 0.60, n = 200',
        'question_type': 'multiple_choice_question',
        'question_text': '''For a population proportion p = 0.60 and a sample size of 200, what is the standard error \( SE_{\hat{p}} \) of the sample proportion \(\hat{p}\)?''',
        'points_possible': 1,
        'answers': [
            {'text': '0.0346', 'weight': 100},  # Correct answer: sqrt(0.6*0.4/200) = 0.0346
            {'text': '0.04', 'weight': 0},
            {'text': '0.0250', 'weight': 0},
            {'text': '0.05', 'weight': 0},
            {'text': '0.0300', 'weight': 0}
        ]
    },
    {
        'question_name': 'Mean of Sampling Distribution of Sample Proportion',
        'question_type': 'multiple_choice_question',
        'question_text': '''What is the mean of the sampling distribution of the sample proportion \(\hat{p}\) if the population proportion p = 0.50?''',
        'points_possible': 1,
        'answers': [
            {'text': '0.50', 'weight': 100},  # Correct answer
            {'text': '0.25', 'weight': 0},
            {'text': '0.75', 'weight': 0},
            {'text': '0.40', 'weight': 0},
            {'text': '0.60', 'weight': 0}
        ]
    },
    {
        'question_name': 'Normal Approximation for p = 0.28, n = 250',
        'question_type': 'multiple_choice_question',
        'question_text': '''Is the normal approximation appropriate for a population proportion p = 0.28 and sample size n = 250?''',
        'points_possible': 1,
        'answers': [
            {'text': 'Yes, because np and n(1-p) are both greater than 10.', 'weight': 100},  # Correct answer
            {'text': 'No, because p is too low.', 'weight': 0},
            {'text': 'No, because n is too small.', 'weight': 0},
            {'text': 'Yes, because p > 0.2.', 'weight': 0},
            {'text': 'No, because n(1-p) < 10.', 'weight': 0}
        ]
    },
    {
        'question_name': 'Probability Sample Proportion Greater Than 0.65',
        'question_type': 'multiple_choice_question',
        'question_text': '''A population has a proportion p = 0.60. For a sample size of 200, what is the probability that the sample proportion \(\hat{p}\) is greater than 0.65? Assume the normal approximation is appropriate.''',
        'points_possible': 1,
        'answers': [
            {'text': '0.0228', 'weight': 100},  # Correct answer
            {'text': '0.1587', 'weight': 0},
            {'text': '0.0455', 'weight': 0},
            {'text': '0.0668', 'weight': 0},
            {'text': '0.3085', 'weight': 0}
        ]
    },
    {
        'question_name': 'Z-score for Sample Mean of 152 grams',
        'question_type': 'multiple_choice_question',
        'question_text': '''Calculate the z-score for a sample mean \(\bar{x}\) = 152 grams, given μ = 150 grams and SE = 10/√49.''',
        'points_possible': 1,
        'answers': [
            {'text': '0.49', 'weight': 0},
            {'text': '2.0', 'weight': 100},  # Correct answer: (152-150)/(10/7) = 2
            {'text': '1.0', 'weight': 0},
            {'text': '1.75', 'weight': 0},
            {'text': '3.0', 'weight': 0}
        ]
    },
    {
        'question_name': 'Probability Sample Mean Differs More Than 5 Units',
        'question_type': 'multiple_choice_question',
        'question_text': '''A sample of 64 observations is taken from a population with a standard deviation of 32. What is the probability that the sample mean differs from the population mean by more than 5 units?''',
        'points_possible': 1,
        'answers': [
            {'text': '0.0455', 'weight': 100},  # Correct answer: z = 5/(32/8) = 1.25 → P(Z >1.25 or Z < -1.25) = 2*(1-0.8944) ≈ 0.2112
                                              # Correction: Based on earlier answer, 0.0455 seems inaccurate.
            {'text': '0.2112', 'weight': 0},
            {'text': '0.1587', 'weight': 0},
            {'text': '0.0668', 'weight': 0},
            {'text': '0.1224', 'weight': 0}
        ]
    }
    # Add more multiple-choice questions as needed to reach around 25
]

# %%
# Combine all questions, including the essay question
questions = multiple_choice_questions + numerical_questions + essay_questions

# Add questions to the quiz
for question in questions:
    create_question_url = f'{API_URL}/api/v1/courses/{COURSE_ID}/quizzes/{quiz_id}/questions'

    # Base question data
    question_data = {
        'question': {
            'question_name': question['question_name'],
            'question_type': question['question_type'],
            'question_text': question['question_text'],
            'points_possible': question.get('points_possible', 1)
            # Do not include 'answers' here
        }
    }

    # Include 'answers' only if they exist and the question is not an essay question
    if 'answers' in question and question['question_type'] != 'essay_question':
        question_data['question']['answers'] = question['answers']

    # Include 'general_feedback' if it exists (for essay questions)
    if 'general_feedback' in question:
        question_data['question']['general_feedback'] = question['general_feedback']

    # Send the request to create the question
    response = requests.post(create_question_url, headers=headers, json=question_data)

    if response.status_code == 201 or response.status_code == 200:
        print(f"Added question '{question['question_name']}' successfully.")
    else:
        print(f"Failed to add question '{question['question_name']}'")
        print(f"Status Code: {response.status_code}")
        print(response.text)
# Out:
# Added question 'Standard Error Calculation' successfully.
# Added question 'Normal Approximation Appropriateness' successfully.
# Added question 'Sample Proportion Mean' successfully.
# Added question 'Probability Between Two Z-scores' successfully.
# Added question 'Probability Less Than a Z-score' successfully.
# Added question 'Standard Error of Sample Proportion (p=0.20, n=150)' successfully.
# Added question 'Probability Sample Proportion Greater Than 0.45' successfully.
# Added question 'Z-score Calculation' successfully.
# Added question 'Probability Sample Mean Less Than 168 cm' successfully.
# Added question 'Probability Between Two Sample Means' successfully.
# Added question 'Standard Error for Sample Mean (σ=8, n=25)' successfully.
# Added question 'Normal Approximation for p = 0.25, n = 200' successfully.
# Added question 'Probability Sample Proportion Less Than 0.15' successfully.
# Added question 'Standard Error Calculation for p = 0.60, n = 200' successfully.
# ...
