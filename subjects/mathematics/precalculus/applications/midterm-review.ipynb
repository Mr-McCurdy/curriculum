# %%
# %pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import json
import os

# %%
#Define path
SECRETS_FILE = '/Users/gmccurdy/repos/curriculum/scripts/utilities/secrets.json'

# Load secrets
with open(SECRETS_FILE, 'r') as file:
    secrets = json.load(file)

# Assign variables from the secrets
API_URL = secrets.get('API_URL')
API_KEY = secrets.get('API_KEY')
COURSE_ID = secrets.get('COURSE_ID_HPRECALCULUS')

#Define headers
headers = {
    'Authorization': f'Bearer {API_KEY}',
    'Content-Type': 'application/json'
}

# %%
# Create the quiz
quiz_title = input('Quiz Title')
quiz_description = input('Quiz Description')
quiz_data = {
    'quiz': {
        'title': quiz_title,
        'description': f'<p>{quiz_description}</p>',
        'quiz_type': 'assignment',
        'published': False
    }
}

create_quiz_url = f'{API_URL}/api/v1/courses/{COURSE_ID}/quizzes'
response = requests.post(create_quiz_url, headers=headers, json=quiz_data)

if response.status_code == 200:
    quiz = response.json()
    quiz_id = quiz['id']
    print(f'Quiz created successfully with ID: {quiz_id}')
else:
    print('Failed to create quiz')
    print(f"Status Code: {response.status_code}")
    print(response.text)
# Out:
# Quiz created successfully with ID: 44095

# %%
multiple_choice_questions = [
    {
        'question_name': 'Evaluate Cosecant of π/4',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \csc \frac{\pi}{4} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( 1 \)', 'weight': 0},
            {'text': r'\( -1 \)', 'weight': 0},
            {'text': r'\( \frac{\sqrt{2}}{2} \)', 'weight': 0},
            {'text': r'\( -\frac{\sqrt{2}}{2} \)', 'weight': 0},
            {'text': r'\( \sqrt{2} \)', 'weight': 100},    # Correct answer
        ]
    },
    {
        'question_name': 'Evaluate Sine of π/6',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \sin \frac{\pi}{6} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( \frac{\sqrt{3}}{2} \)', 'weight': 0},
            {'text': r'\( -\frac{1}{2} \)', 'weight': 0},
            {'text': r'\( 1 \)', 'weight': 0},
            {'text': r'\( -1 \)', 'weight': 0},
            {'text': r'\( \frac{1}{2} \)', 'weight': 100},  # Correct answer
        ]
    },
    {
        'question_name': 'Evaluate Sine of 3π/2',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \sin \frac{3\pi}{2} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( 1 \)', 'weight': 0},
            {'text': r'\( \frac{1}{2} \)', 'weight': 0},
            {'text': r'\( 0 \)', 'weight': 0},
            {'text': r'\( \frac{\sqrt{3}}{2} \)', 'weight': 0},
            {'text': r'\( -1 \)', 'weight': 100},         # Correct answer
        ]
    },
    {
        'question_name': 'Evaluate Tangent of 3π/4',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \tan \frac{3\pi}{4} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( -1 \)', 'weight': 100},          # Correct answer
            {'text': r'\( 1 \)', 'weight': 0},
            {'text': r'\( \sqrt{3} \)', 'weight': 0},
            {'text': r'\( -\sqrt{3} \)', 'weight': 0},
            {'text': r'\( 0 \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Evaluate Secant of 7π/6',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \sec \frac{7\pi}{6} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( \frac{2}{\sqrt{3}} \)', 'weight': 0},
            {'text': r'\( -\frac{2}{\sqrt{3}} \)', 'weight': 100},  # Correct answer
            {'text': r'\( 2 \)', 'weight': 0},
            {'text': r'\( -2 \)', 'weight': 0},
            {'text': r'\( \sqrt{3} \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Evaluate Sine of 7π/6',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \sin \frac{7\pi}{6} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( \frac{1}{2} \)', 'weight': 0},
            {'text': r'\( -\frac{\sqrt{3}}{2} \)', 'weight': 0},
            {'text': r'\( \frac{\sqrt{3}}{2} \)', 'weight': 0},
            {'text': r'\( -\frac{1}{2} \)', 'weight': 100},  # Correct answer
            {'text': r'\( 0 \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Evaluate Cosine of 5π/3',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \cos \frac{5\pi}{3} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( -\frac{1}{2} \)', 'weight': 0},
            {'text': r'\( -\frac{\sqrt{3}}{2} \)', 'weight': 0},
            {'text': r'\( 1 \)', 'weight': 0},
            {'text': r'\( -1 \)', 'weight': 0},
            {'text': r'\( \frac{1}{2} \)', 'weight': 100},    # Correct answer
        ]
    },
    {
        'question_name': 'Evaluate Sine of π/4',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \sin \frac{\pi}{4} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( 1 \)', 'weight': 0},
            {'text': r'\( -1 \)', 'weight': 0},
            {'text': r'\( \frac{\sqrt{2}}{2} \)', 'weight': 100},  # Correct answer
            {'text': r'\( -\frac{\sqrt{2}}{2} \)', 'weight': 0},
            {'text': r'\( 0 \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Evaluate Cosecant of 3π/4',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \csc \frac{3\pi}{4} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( \sqrt{2} \)', 'weight': 100},    # Correct answer
            {'text': r'\( -\sqrt{2} \)', 'weight': 0},
            {'text': r'\( 1 \)', 'weight': 0},
            {'text': r'\( -1 \)', 'weight': 0},
            {'text': r'\( \frac{\sqrt{2}}{2} \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Evaluate Cosine of π/6',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \cos \frac{\pi}{6} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( 0 \)', 'weight': 0},
            {'text': r'\( -\frac{\sqrt{3}}{2} \)', 'weight': 0},
            {'text': r'\( 1 \)', 'weight': 0},
            {'text': r'\( -1 \)', 'weight': 0},
            {'text': r'\( \frac{\sqrt{3}}{2} \)', 'weight': 100},  # Correct answer
        ]
    },
    {
        'question_name': 'Evaluate Secant of 0',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \sec 0 \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( -1 \)', 'weight': 0},
            {'text': r'\( 0 \)', 'weight': 0},
            {'text': r'\( \infty \)', 'weight': 0},
            {'text': r'\( \text{Undefined} \)', 'weight': 0},
            {'text': r'\( 1 \)', 'weight': 100},        # Correct answer
        ]
    },
    {
        'question_name': 'Evaluate Sine of π/3',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \sin \frac{\pi}{3} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( \frac{1}{2} \)', 'weight': 0},
            {'text': r'\( \frac{\sqrt{3}}{3} \)', 'weight': 0},
            {'text': r'\( -\frac{\sqrt{3}}{2} \)', 'weight': 0},
            {'text': r'\( -\frac{1}{2} \)', 'weight': 0},
            {'text': r'\( \frac{\sqrt{3}}{2} \)', 'weight': 100},  # Correct answer
        ]
    },
    {
        'question_name': 'Evaluate Secant of 4π/3',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \sec \frac{4\pi}{3} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( 2 \)', 'weight': 0},
            {'text': r'\( -\frac{2}{\sqrt{3}} \)', 'weight': 100},  # Correct answer
            {'text': r'\( \frac{2}{\sqrt{3}} \)', 'weight': 0},
            {'text': r'\( -2 \)', 'weight': 0},
            {'text': r'\( 0 \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Evaluate Tangent of π/2',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \tan \frac{\pi}{2} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( 1 \)', 'weight': 0},
            {'text': r'\( -1 \)', 'weight': 0},
            {'text': r'\( 0 \)', 'weight': 0},
            {'text': r'\( \infty \)', 'weight': 0},
            {'text': r'\( \text{Undefined} \)', 'weight': 100},  # Correct answer
        ]
    },
    {
        'question_name': 'Evaluate Cotangent of 0',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \cot 0 \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( 1 \)', 'weight': 0},
            {'text': r'\( 0 \)', 'weight': 0},
            {'text': r'\( \infty \)', 'weight': 0},
            {'text': r'\( -1 \)', 'weight': 0},
            {'text': r'\( \text{Undefined} \)', 'weight': 100},  # Correct answer
        ]
    },
    {
        'question_name': 'Evaluate Cosine of π/2',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \cos \frac{\pi}{2} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( 1 \)', 'weight': 0},
            {'text': r'\( -1 \)', 'weight': 0},
            {'text': r'\( \infty \)', 'weight': 0},
            {'text': r'\( \text{Undefined} \)', 'weight': 0},
            {'text': r'\( 0 \)', 'weight': 100},        # Correct answer
        ]
    },
    {
        'question_name': 'Evaluate Tangent of 5π/4',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \tan \frac{5\pi}{4} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( -1 \)', 'weight': 0},
            {'text': r'\( 0 \)', 'weight': 0},
            {'text': r'\( \sqrt{3} \)', 'weight': 0},
            {'text': r'\( -\sqrt{3} \)', 'weight': 0},
            {'text': r'\( 1 \)', 'weight': 100},        # Correct answer
        ]
    },
    {
        'question_name': 'Evaluate Tangent of 3π/2',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \tan \frac{3\pi}{2} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( 1 \)', 'weight': 0},
            {'text': r'\( -1 \)', 'weight': 0},
            {'text': r'\( 0 \)', 'weight': 0},
            {'text': r'\( \infty \)', 'weight': 0},
            {'text': r'\( \text{Undefined} \)', 'weight': 100},  # Correct answer
        ]
    },
]

multiple_choice_questions += [
    {
        'question_name': 'Evaluate Secant of -5π',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \sec -5\pi \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( 1 \)', 'weight': 0},
            {'text': r'\( -1 \)', 'weight': 100},       # Correct answer
            {'text': r'\( \text{Undefined} \)', 'weight': 0},
            {'text': r'\( 0 \)', 'weight': 0},
            {'text': r'\( \frac{\sqrt{3}}{2} \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Evaluate Cotangent of -11π/6',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \cot \left(-\frac{11\pi}{6}\right) \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( \sqrt{3} \)', 'weight': 0},
            {'text': r'\( -\sqrt{3} \)', 'weight': 100},  # Correct answer
            {'text': r'\( 0 \)', 'weight': 0},
            {'text': r'\( \text{Undefined} \)', 'weight': 0},
            {'text': r'\( \frac{1}{\sqrt{3}} \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Evaluate Cosine of 13π/3',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \cos \frac{13\pi}{3} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( -0.5 \)', 'weight': 0},
            {'text': r'\( 0.5 \)', 'weight': 100},       # Correct answer
            {'text': r'\( \frac{\sqrt{3}}{2} \)', 'weight': 0},
            {'text': r'\( -\frac{\sqrt{3}}{2} \)', 'weight': 0},
            {'text': r'\( 1 \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Evaluate Sine of -13π/6',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \sin \left(-\frac{13\pi}{6}\right) \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( 0.5 \)', 'weight': 0},
            {'text': r'\( -0.5 \)', 'weight': 100},      # Correct answer
            {'text': r'\( 1 \)', 'weight': 0},
            {'text': r'\( -1 \)', 'weight': 0},
            {'text': r'\( \frac{\sqrt{3}}{2} \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Evaluate Cosine of 13π/6',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \cos \frac{13\pi}{6} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( -\frac{\sqrt{3}}{2} \)', 'weight': 0},
            {'text': r'\( \frac{\sqrt{3}}{2} \)', 'weight': 100},  # Correct answer
            {'text': r'\( -\frac{1}{2} \)', 'weight': 0},
            {'text': r'\( \frac{1}{2} \)', 'weight': 0},
            {'text': r'\( 0 \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Evaluate Tangent of -23π/6',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \tan \left(-\frac{23\pi}{6}\right) \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( \sqrt{3} \)', 'weight': 0},
            {'text': r'\( -\sqrt{3} \)', 'weight': 0},
            {'text': r'\( \frac{1}{\sqrt{3}} \)', 'weight': 100},  # Correct answer
            {'text': r'\( -\frac{1}{\sqrt{3}} \)', 'weight': 0},
            {'text': r'\( 0 \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Evaluate Secant of 3π/4',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \sec \frac{3\pi}{4} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( \sqrt{2} \)', 'weight': 0},
            {'text': r'\( -\sqrt{2} \)', 'weight': 100},  # Correct answer
            {'text': r'\( \frac{2}{\sqrt{3}} \)', 'weight': 0},
            {'text': r'\( -\frac{2}{\sqrt{3}} \)', 'weight': 0},
            {'text': r'\( 1 \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Evaluate Secant of -11π/6',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \sec \left(-\frac{11\pi}{6}\right) \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( \frac{2}{\sqrt{3}} \)', 'weight': 100},  # Correct answer
            {'text': r'\( -\frac{2}{\sqrt{3}} \)', 'weight': 0},
            {'text': r'\( \frac{\sqrt{3}}{2} \)', 'weight': 0},
            {'text': r'\( -\frac{\sqrt{3}}{2} \)', 'weight': 0},
            {'text': r'\( 1 \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Evaluate Secant of -2π/3',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \sec \left(-\frac{2\pi}{3}\right) \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( 2 \)', 'weight': 0},
            {'text': r'\( -2 \)', 'weight': 100},         # Correct answer
            {'text': r'\( \text{Undefined} \)', 'weight': 0},
            {'text': r'\( 0 \)', 'weight': 0},
            {'text': r'\( \frac{\sqrt{3}}{2} \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Evaluate Cotangent of 11π/4',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Evaluate \( \cot \frac{11\pi}{4} \).''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( 1 \)', 'weight': 100},           # Correct answer
            {'text': r'\( -1 \)', 'weight': 0},
            {'text': r'\( 0 \)', 'weight': 0},
            {'text': r'\( \text{Undefined} \)', 'weight': 0},
            {'text': r'\( \sqrt{3} \)', 'weight': 0},
        ]
    },
]

multiple_choice_questions += [
    {
        'question_name': 'Solve -1 = sin(theta)',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Solve \( -1 = \sin \theta \) for \( 0 \leq \theta < 2\pi \). What is \( \theta \)?''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( \theta = \frac{\pi}{2} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{3\pi}{2} \)', 'weight': 100},  # Correct answer
            {'text': r'\( \theta = \pi \)', 'weight': 0},
            {'text': r'\( \theta = 0 \)', 'weight': 0},
            {'text': r'\( \theta = 2\pi \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Solve 2 = csc(theta)',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Solve \( 2 = \csc \theta \) for \( 0 \leq \theta < 2\pi \). What are the possible values of \( \theta \)?''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( \theta = \frac{\pi}{6}, \frac{5\pi}{6} \)', 'weight': 100},  # Correct answer
            {'text': r'\( \theta = \frac{\pi}{3}, \frac{2\pi}{3} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{4}, \frac{3\pi}{4} \)', 'weight': 0},
            {'text': r'\( \theta = 0, \pi \)', 'weight': 0},
            {'text': r'\( \theta = \frac{7\pi}{6}, \frac{11\pi}{6} \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Solve sqrt(3) = cot(theta)',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Solve \( \sqrt{3} = \cot \theta \) for \( 0 \leq \theta < 2\pi \). What are the possible values of \( \theta \)?''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( \theta = \frac{\pi}{6}, \frac{7\pi}{6} \)', 'weight': 100},  # Correct answer
            {'text': r'\( \theta = \frac{\pi}{4}, \frac{5\pi}{4} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{3}, \frac{4\pi}{3} \)', 'weight': 0},
            {'text': r'\( \theta = 0, \pi \)', 'weight': 0},
            {'text': r'\( \theta = \frac{3\pi}{2}, \frac{9\pi}{2} \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Solve 0 = tan(theta)',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Solve \( 0 = \tan \theta \) for \( 0 \leq \theta < 2\pi \). What are the possible values of \( \theta \)?''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( \theta = 0, \pi \)', 'weight': 100},  # Correct answer
            {'text': r'\( \theta = \frac{\pi}{2}, \frac{3\pi}{2} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{4}, \frac{5\pi}{4} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{6}, \frac{7\pi}{6} \)', 'weight': 0},
            {'text': r'\( \theta = 2\pi \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Solve -1/2 = sin(theta)',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Solve \( -\frac{1}{2} = \sin \theta \) for \( 0 \leq \theta < 2\pi \). What are the possible values of \( \theta \)?''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( \theta = \frac{7\pi}{6}, \frac{11\pi}{6} \)', 'weight': 100},  # Correct answer
            {'text': r'\( \theta = \frac{\pi}{6}, \frac{5\pi}{6} \)', 'weight': 0},
            {'text': r'\( \theta = \pi, 2\pi \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{2}, \frac{3\pi}{2} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{3\pi}{4}, \frac{5\pi}{4} \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Solve -sqrt(2) = csc(theta)',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Solve \( -\sqrt{2} = \csc \theta \) for \( 0 \leq \theta < 2\pi \). What are the possible values of \( \theta \)?''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( \theta = \frac{5\pi}{4}, \frac{7\pi}{4} \)', 'weight': 100},  # Correct answer
            {'text': r'\( \theta = \frac{\pi}{4}, \frac{3\pi}{4} \)', 'weight': 0},
            {'text': r'\( \theta = \pi, 2\pi \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{6}, \frac{5\pi}{6} \)', 'weight': 0},
            {'text': r'\( \theta = 0, \pi \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Solve sqrt(3) = tan(theta)',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Solve \( \sqrt{3} = \tan \theta \) for \( 0 \leq \theta < 2\pi \). What are the possible values of \( \theta \)?''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( \theta = \frac{\pi}{3}, \frac{4\pi}{3} \)', 'weight': 100},  # Correct answer
            {'text': r'\( \theta = \frac{\pi}{6}, \frac{7\pi}{6} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{4}, \frac{5\pi}{4} \)', 'weight': 0},
            {'text': r'\( \theta = 0, \pi \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{2}, \frac{3\pi}{2} \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Solve sin(theta) = sqrt(3)/2',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Solve \( \sin \theta = \frac{\sqrt{3}}{2} \) for \( 0 \leq \theta < 2\pi \). What are the possible values of \( \theta \)?''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( \theta = \frac{\pi}{3}, \frac{2\pi}{3} \)', 'weight': 100},  # Correct answer
            {'text': r'\( \theta = \frac{\pi}{6}, \frac{5\pi}{6} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{4}, \frac{7\pi}{4} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{2}, \frac{3\pi}{2} \)', 'weight': 0},
            {'text': r'\( \theta = 0, \pi \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Solve tan(theta) = 1',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Solve \( \tan \theta = 1 \) for \( 0 \leq \theta < 2\pi \). What are the possible values of \( \theta \)?''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( \theta = \frac{\pi}{4}, \frac{5\pi}{4} \)', 'weight': 100},  # Correct answer
            {'text': r'\( \theta = \frac{\pi}{6}, \frac{7\pi}{6} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{3}, \frac{4\pi}{3} \)', 'weight': 0},
            {'text': r'\( \theta = 0, \pi \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{2}, \frac{3\pi}{2} \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Solve csc(theta) = -2sqrt(3)/3',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Solve \( \csc \theta = -\frac{2\sqrt{3}}{3} \) for \( 0 \leq \theta < 2\pi \). What are the possible values of \( \theta \)?''',
        'points_possible': 1,
        'answers': [
            {'text': r'\( \theta = \frac{4\pi}{3}, \frac{5\pi}{3} \)', 'weight': 100},  # Correct answer
            {'text': r'\( \theta = \frac{\pi}{3}, \frac{2\pi}{3} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{6}, \frac{7\pi}{6} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{4}, \frac{7\pi}{4} \)', 'weight': 0},
            {'text': r'\( \theta = \pi, 2\pi \)', 'weight': 0},
        ]
    },
]

multiple_choice_questions += [
    {
        'question_name': 'Solve sec²(theta) + 2 sec(theta) = 0',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Solve \( \sec^2 \theta + 2 \sec \theta = 0 \) for \( 0 \leq \theta < 2\pi \). What are the possible values of \( \theta \)?''',
        'points_possible': 2,
        'answers': [
            {'text': r'\( \theta = \frac{\pi}{3}, \frac{5\pi}{3} \)', 'weight': 0},
            {'text': r'\( \theta = 0, \pi \)', 'weight': 0},
            {'text': r'\( \theta = \frac{2\pi}{3}, \frac{4\pi}{3} \)', 'weight': 100},  # Correct answer
            {'text': r'\( \theta = \frac{\pi}{6}, \frac{7\pi}{6} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{4}, \frac{3\pi}{4} \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Solve -2 cos(theta) = -3 sin(theta) + 2 sqrt(3) sin(theta) cos(theta) - 2 cos(theta)',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Solve \( -2 \cos \theta = -3 \sin \theta + 2 \sqrt{3} \sin \theta \cos \theta - 2 \cos \theta \) for \( 0 \leq \theta < 2\pi \). What are the possible values of \( \theta \)?''',
        'points_possible': 2,
        'answers': [
            {'text': r'\( \theta = \frac{\pi}{6}, \frac{5\pi}{6} \)', 'weight': 0},
            {'text': r'\( \theta = 0, \pi, \frac{\pi}{6}, \frac{11\pi}{6} \)', 'weight': 100},  # Correct answer
            {'text': r'\( \theta = \frac{\pi}{3}, \frac{4\pi}{3} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{2}, \frac{3\pi}{2} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{4}, \frac{3\pi}{4} \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Solve cot(theta) - cot²(theta) = -sqrt(3) cot²(theta) - cot²(theta)',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Solve \( \cot \theta - \cot^2 \theta = -\sqrt{3} \cot^2 \theta - \cot^2 \theta \) for \( 0 \leq \theta < 2\pi \). What are the possible values of \( \theta \)?''',
        'points_possible': 2,
        'answers': [
            {'text': r'\( \theta = \frac{\pi}{6}, \frac{7\pi}{6} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{3}, \frac{4\pi}{3} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{2}, \frac{3\pi}{2}, \frac{2\pi}{3}, \frac{5\pi}{3} \)', 'weight': 100},  # Correct answer
            {'text': r'\( \theta = \frac{\pi}{4}, \frac{5\pi}{4} \)', 'weight': 0},
            {'text': r'\( \theta = 0, \pi \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Solve 2 cot²(theta) + 2 cot(theta) = -1 + cot²(theta)',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Solve \( 2 \cot^2 \theta + 2 \cot \theta = -1 + \cot^2 \theta \) for \( 0 \leq \theta < 2\pi \). What are the possible values of \( \theta \)?''',
        'points_possible': 2,
        'answers': [
            {'text': r'\( \theta = \frac{\pi}{6}, \frac{7\pi}{6} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{3\pi}{4}, \frac{7\pi}{4} \)', 'weight': 100},  # Correct answer
            {'text': r'\( \theta = \frac{\pi}{3}, \frac{4\pi}{3} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{2}, \frac{3\pi}{2} \)', 'weight': 0},
            {'text': r'\( \theta = 0, \pi \)', 'weight': 0},
        ]
    },
    {
        'question_name': 'Solve 0 = 3 csc(theta) + 3 + cot²(theta)',
        'question_type': 'multiple_choice_question',
        'question_text': r'''Solve \( 0 = 3 \csc \theta + 3 + \cot^2 \theta \) for \( 0 \leq \theta < 2\pi \). What are the possible values of \( \theta \)?''',
        'points_possible': 2,
        'answers': [
            {'text': r'\( \theta = \frac{3\pi}{2}, \frac{7\pi}{6}, \frac{11\pi}{6} \)', 'weight': 100},  # Correct answer
            {'text': r'\( \theta = \frac{\pi}{6}, \frac{5\pi}{6} \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{3}, \frac{4\pi}{3} \)', 'weight': 0},
            {'text': r'\( \theta = 0, \pi \)', 'weight': 0},
            {'text': r'\( \theta = \frac{\pi}{2}, \frac{3\pi}{2} \)', 'weight': 0},
        ]
    },
]

# %%
essay_questions = [
    
]

# %%
numerical_questions = [
    {
        'question_name': 'Convert Negative Radians to Degrees -π/3',
        'question_type': 'numerical_question',
        'question_text': r'''Convert \( -\frac{\pi}{3} \) radians to degrees. Provide your answer as an integer.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '-60'  # Correct answer: (-π/3) * (180/π) = -60 degrees
            }
        ]
    },
    {
        'question_name': 'Convert Radians Greater Than 2π to Degrees -9π/4',
        'question_type': 'numerical_question',
        'question_text': r'''Convert \( \frac{9\pi}{4} \) radians to degrees. Provide your answer as an integer.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '405'  # Correct answer: (9π/4) * (180/π) = 405 degrees
            }
        ]
    },
    {
        'question_name': 'Convert Negative Radians to Degrees -2π/3',
        'question_type': 'numerical_question',
        'question_text': r'''Convert \( -\frac{2\pi}{3} \) radians to degrees. Provide your answer as an integer.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '-120'  # Correct answer: (-2π/3) * (180/π) = -120 degrees
            }
        ]
    },
    {
        'question_name': 'Convert Radians Greater Than 2π to Degrees -13π/6',
        'question_type': 'numerical_question',
        'question_text': r'''Convert \( \frac{13\pi}{6} \) radians to degrees. Provide your answer as an integer.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '390'  # Correct answer: (13π/6) * (180/π) = 390 degrees
            }
        ]
    },
    {
        'question_name': 'Convert Negative Radians to Degrees -5π/4',
        'question_type': 'numerical_question',
        'question_text': r'''Convert \( -\frac{5\pi}{4} \) radians to degrees. Provide your answer as an integer.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '-225'  # Correct answer: (-5π/4) * (180/π) = -225 degrees
            }
        ]
    },
    {
        'question_name': 'Convert Radians Greater Than 2π to Degrees -7π/3',
        'question_type': 'numerical_question',
        'question_text': r'''Convert \( -\frac{7\pi}{3} \) radians to degrees. Provide your answer as an integer.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '-420'  # Correct answer: (-7π/3) * (180/π) = -420 degrees
            }
        ]
    },
]

numerical_questions += [
    {
        'question_name': 'Convert Radians Greater Than 2pi to Degrees 11pi/6',
        'question_type': 'numerical_question',
        'question_text': r'''Convert \( \frac{11\pi}{6} \) radians to degrees. Provide your answer as an integer.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '330'  # Correct answer: (11π/6) * (180/π) = 330 degrees
            }
        ]
    },
    {
        'question_name': 'Convert Negative Radians to Degrees -pi/2',
        'question_type': 'numerical_question',
        'question_text': r'''Convert \( -\frac{\pi}{2} \) radians to degrees. Provide your answer as an integer.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '-90'  # Correct answer: (-π/2) * (180/π) = -90 degrees
            }
        ]
    },
    {
        'question_name': 'Convert Radians Greater Than 2pi to Degrees 5pi',
        'question_type': 'numerical_question',
        'question_text': r'''Convert \( 5\pi \) radians to degrees. Provide your answer as an integer.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '900'  # Correct answer: (5π) * (180/π) = 900 degrees
            }
        ]
    },
    {
        'question_name': 'Convert Negative Radians to Degrees -4pi/3',
        'question_type': 'numerical_question',
        'question_text': r'''Convert \( -\frac{4\pi}{3} \) radians to degrees. Provide your answer as an integer.''',
        'points_possible': 1,
        'answers': [
            {
                'numerical_answer_type': 'exact_answer',
                'answer_exact': '-240'  # Correct answer: (-4π/3) * (180/π) = -240 degrees
            }
        ]
    },
]

# %%
# Combine all questions, including the essay question
questions = multiple_choice_questions + numerical_questions + essay_questions

# Add questions to the quiz
for question in questions:
    create_question_url = f'{API_URL}/api/v1/courses/{COURSE_ID}/quizzes/{quiz_id}/questions'

    # Base question data
    question_data = {
        'question': {
            'question_name': question['question_name'],
            'question_type': question['question_type'],
            'question_text': question['question_text'],
            'points_possible': question.get('points_possible', 1)
            # Do not include 'answers' here
        }
    }

    # Include 'answers' only if they exist and the question is not an essay question
    if 'answers' in question and question['question_type'] != 'essay_question':
        question_data['question']['answers'] = question['answers']

    # Include 'general_feedback' if it exists (for essay questions)
    if 'general_feedback' in question:
        question_data['question']['general_feedback'] = question['general_feedback']

    # Send the request to create the question
    response = requests.post(create_question_url, headers=headers, json=question_data)

    if response.status_code == 201 or response.status_code == 200:
        print(f"Added question '{question['question_name']}' successfully.")
    else:
        print(f"Failed to add question '{question['question_name']}'")
        print(f"Status Code: {response.status_code}")
        print(response.text)
# Out:
# Added question 'Evaluate Cosecant of π/4' successfully.
# Added question 'Evaluate Sine of π/6' successfully.
# Added question 'Evaluate Sine of 3π/2' successfully.
# Added question 'Evaluate Tangent of 3π/4' successfully.
# Added question 'Evaluate Secant of 7π/6' successfully.
# Added question 'Evaluate Sine of 7π/6' successfully.
# Added question 'Evaluate Cosine of 5π/3' successfully.
# Added question 'Evaluate Sine of π/4' successfully.
# Added question 'Evaluate Cosecant of 3π/4' successfully.
# Added question 'Evaluate Cosine of π/6' successfully.
# Added question 'Evaluate Secant of 0' successfully.
# Added question 'Evaluate Sine of π/3' successfully.
# Added question 'Evaluate Secant of 4π/3' successfully.
# Added question 'Evaluate Tangent of π/2' successfully.
# Added question 'Evaluate Cotangent of 0' successfully.
# Added question 'Evaluate Cosine of π/2' successfully.
# Added question 'Evaluate Tangent of 5π/4' successfully.
# ...
